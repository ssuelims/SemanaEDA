# %% [markdown]
# # Music IA Education

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Coleta de dados
#
# - Questionario via Google Forms
# - Perguntas sobre a faixa etaria, professor e estilo musical

# %% [markdown]
# ## Objetivo do Experimento
# <span style="font-size:1em;">
#
# - Criar usica com ritmos e estilos musicais adquados
# para uma turma especifica.
#
# - As músicas tem objetivo de auxiliar o professor com o recurso didatico
# sendo que as letras das canções abordarao o conteudo ministrado pelo professor
#
# - As musicas serao geradas por IA no software SUNO e disponibilizado em forma de link.
# </span>

# %% [markdown]
# ## METODOS
# - NOME
# - head()
# - info()
# - describ()

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/pesquisamusicalv2.csv')

# %%
# Visualizar o dataframe

df.head()
# Out:
#                   data  rock  hiphop  mpb  reggea  funk  sertanejo  gospel  \
# 0  21/08/2024 10:03:25     3       1    1       1     1          1       1
# 1  21/08/2024 10:04:39     5       3    5       2     1          3       1
# 2  21/08/2024 10:04:52     1       5    1       1     1          1       1
# 3  21/08/2024 10:04:53     1       5    4       4     4          1       1
# 4  21/08/2024 10:04:55     5       4    3       4     1          1       2
#
#    eletronica professor faixa_etaria
# 0           3       NaN          NaN
# 1           5       NaN          NaN
# 2           5       NaN          NaN
# 3           5       NaN          NaN
# 4           5       NaN          NaN

# %%
df.describe()
# Out:
#             rock     hiphop        mpb     reggea       funk  sertanejo  \
# count  95.000000  95.000000  95.000000  95.000000  95.000000  95.000000
# mean    3.263158   3.084211   3.242105   2.578947   2.431579   2.884211
# std     1.545140   1.534450   1.396925   1.411043   1.492197   1.457652
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     2.000000   1.500000   2.000000   1.000000   1.000000   1.500000
# 50%     4.000000   3.000000   4.000000   2.000000   2.000000   3.000000
# 75%     5.000000   4.500000   4.000000   3.500000   4.000000   4.000000
# max     5.000000   5.000000   5.000000   5.000000   5.000000   5.000000
#
#           gospel  eletronica
# count  95.000000   95.000000
# mean    2.652632    3.189474
# std     1.493022    1.573009
# min     1.000000    1.000000
# 25%     1.000000    1.000000
# 50%     2.000000    4.000000
# 75%     4.000000    5.000000
# max     5.000000    5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data          95 non-null     object
#  1   rock          95 non-null     int64
#  2   hiphop        95 non-null     int64
#  3   mpb           95 non-null     int64
#  4   reggea        95 non-null     int64
#  5   funk          95 non-null     int64
#  6   sertanejo     95 non-null     int64
#  7   gospel        95 non-null     int64
#  8   eletronica    95 non-null     int64
#  9   professor     57 non-null     object
#  10  faixa_etaria  57 non-null     object
# dtypes: int64(8), object(3)
# memory usage: 8.3+ KB

# %%
# Comando para renomear colunas 
df.columns = ["data","rock","hiphop","mpb","reggea","funk","sertanejo","gospel","eletronica","professor","faixa_etaria"]
